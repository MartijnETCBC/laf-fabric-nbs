# %% [markdown]
# <a href="http://laf-fabric.readthedocs.org/en/latest/" target="_blank"><img align="left" src="images/laf-fabric-xsmall.png"/></a>
# <a href="http://www.godgeleerdheid.vu.nl/etcbc" target="_blank"><img align="left" src="images/VU-ETCBC-xsmall.png"/></a>
# <a href="http://tla.mpi.nl" target="_blank"><img align="right" src="images/TLA-xsmall.png"/></a>
# <a href="http://www.dans.knaw.nl" target="_blank"><img align="right"src="images/DANS-xsmall.png"/></a>

# %% [markdown]
# # Plain Text

# %% [markdown]
# # Text from features

# %% [markdown]
# Here comes the plain text of the CALAP data.
#
# The CALAP database only contains the surface consonants as textual representation.

# %%
import sys
import collections

from laf.fabric import LafFabric
fabric = LafFabric()
# Out:
#   0.00s This is LAF-Fabric 4.2.1
# http://laf-fabric.readthedocs.org/texts/API-reference.html

# %%
fabric.load('calap', '--', 'plain', {
    "xmlids": {"node": False, "edge": False},
    "features": ('''
        otype
        surface_consonants
        psp
        book chapter verse verse_label
    ''',''),
    "primary": True,
})
exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s INFO: DATA COMPILED AT: 2014-04-17T16-36-33
#   0.09s LOGFILE=/Users/dirk/laf-fabric-data/calap/tasks/plain/__log__plain.txt
#   0.09s INFO: DATA LOADED FROM SOURCE calap AND ANNOX -- FOR TASK plain

# %%
plain_file = outfile("calap_plain.txt")

for i in F.otype.s('word'):
    the_text = F.surface_consonants.v(i)
    plain_file.write(the_text + ' ')

plain_file.close()

# %%
# !head -n 10 {my_file('calap_plain.txt')}
# Out:
# W MLK> DWJD S>B W <L B CNJ> W MKSJN HWW LH B LBWC> W L> CXN W >MRW LH <BDWHJ H> <BDJK QDMJK NB<WN L MRN MLK> <LJMT> BTWLT> W TQWM QDM MLK> W THW> LH MCMCNJT> W TCKB B <WBK W NCXN L MRN MLK> W B<W <LJMT> D CPJR> B KLH TXWM> D >JSRJL W >CKXW L >BJCG CJLWMJT> W >JTJWH L MLK> W <LJMT> CPJR> HWT B XZWH VB W HWT L MLK> MCMCNJT> W MCMC> LH W MLK> L> JD<H W >DWNJ> BR XGJT MTRWRB W >MR >N> >MLK W <BD LH MRKBT> W PRC> W XMCJN GBRJN D RHVJN HWW QDMWHJ W L> K>> BH >BWHJ MN JWMWHJ W >MR LH MVL MN> HKN> <BD >NT W >P HW CPJR HW> B XZWH VB W LH JLDT BTR >BCLWM W HWW PTGMWHJ <M JW>B BR YWRJ> W <M >BJTR KHN> W M<DRJN BTR >DWNJ> W YDWQ KHN> W BNJ> BR JWJD< W NTN NBJ> W CM<J W D<J W GNBR> D DWJD L> HWW BTR >DWNJ> W DBX >DWNJ> <N> W TWR> W MPVM> <L K>P> RBT> D <L GB <JN QYR> W QR> L KLHWN >XWHJ BNJ MLK> W L KLHWN D BJT JHWD> W L <BDJ MLK> W L NTN NBJ> W L BNJ> BR JWJD< W L GNBR> D DWJD W L CLJMWN >XWHJ L> QR> W >MR NTN NBJ> L BTCB< >MH D CLJMWN L> CM<TJ D >MLK >DWNJ> W MRN DWJD
WR MNH VWBWHJ L GBR> D >CKX RXM> W MCT<> L >DN> D CM<> VWBWHJ L GBR> D L> TBRTH MSKNWT> W L> TBRTH <NWJWT> DXLTH D >LH> <L KLHJN HLJN >TTRJMT RJC DXLTH D MRJ> L MRXMH W RJC HJMNWT> L M>ZL BTRH >XWDJH BRJ W L> TRPJH MVL D L JT >KWTH KL MXW> W L> >JK MXWT> D LB> W KL BJCN W L> >JK BJCWTH D >NTT> KL >WLYNJN W L> >JK >WLYN> D SN>> W KL PWR<NJN W L> >JK PWR<N> D B<LDBB> L JT RC> MRJR> MN RJCH D XWJ> W L JT B<LDBBWT> D MRJR> MN D >NTT> PQX L M<MR LWT >RJ> W LWT TNJN> MN D L M<MR <M >NTT> BJCT> B GW BJT> BJCWTH D >NTT> BJCT> TWRQ >NJN >PWHJ D B<LH W TWKM >NJN >JK GWN> D SQ> BJNT XBRWHJ JTB B<LH D SKLT> W D L> B YBJNH MTTNX SGJ>> BJCT> W L> >JK Z<WRWT BJCWTH D >NTT> PYT> D XVH> TPL <LJH >JK MSQT> D XL> B RGLWHJ D GBR> QCJC> HKN> HJ >NTT> D LCNH >RJK LWT GBR> MKJK> L> TCTDL L CWPRH D >NTT> BJCT> W >P N >JT LH NKS> L> TTRGRG LH MVL D PWLXN> QCJ> W BHTT> BJCT> >NTT> D SRX> <L B<LH W LB> D <MH MXPJ> XCWK> W MXWT> D LB> >NTT> BJCT> RPJWT> D >JDJ> W TBR> D BWRK> >NTT> D L> MJQR> W MCBX> B<LH MN >NTT> CRJW XVH> W MVLTH KLN MJTJN XNN L> TTL L MJ> MPQN> W L >NTT> BJCT> >P> W CWLVN> >JK TWR<T> GJR D MJ> D >ZL> W SGJ> HKN> >NTT> BJCT> >ZL> W XVJ> W > L> >JTJH >TJ> BTRK BSRK QYY HB LH W CRJH MN BJTK >NTT> VBT> VWBWHJ L B<LH MVL D JWMT> D XJWHJ ><JPJN >NWN >NTT> VBT> TTJHB L GBR> D DXL MN MRJ> XLP <BDWHJ VB> >NTT> XJLTNJT> TBSM B<LH W CNJ XJWHJ B XDWT> NCLM >N <TJR W >N MSKJN LBH VB B KWL <DN W >PWHJ NHJRN MN TLT Z< LBJ W MN >RB< SGJ DXLT RVWNJ> D KNWCT> B SWG>> D <M> W MXWT> D LCN> KLHJN >K XD> NJR> QCJ> >NTT> BJCT> W MN D MSJBR LH >XD <QRB> RWGZ> RB> >NTT> RWJT> W PHJT> HJ Y<RH L> MKSJ> ZNJWTH D >NTT> B MRMWT <JNJH W MN GBJNJH TTJD< <L XYJPT> >SG> NVWR> MVL D L JT LH NJX> > L> >N GNBT BTR XYJPT <JN> HRV W L> TCTWXR DLM> TDGL BK >JK YHJ> D <>L MN >WRX> W PWMH PTJX L MJ> QRJR> W MN KL MJN CT> W <L KL QJS MSTMK W QDM KL G>R> PTJX QVRQH HKN> HJ >NTT> GJRT> D L KL >NC PTJX RXMH MWHBTH D MRJ> >NTT> VBT> W L JT DMJ> L BYJRWT GGRT> VJBWT> <L VJBWT> >NTT> BHWTTNJT> W L JT MTQL> L BYJRWT PWM> >JK CMC> D DNX B RQJ<> D CMJ> HKN> CWPRH D >NTT> VBT> B MWTB BJTH >JK CRG> D MNHR <L MNRT> D QWDC> CWPRH D >NTT> B MQM BJTH >JK XWMR> D DHB> <L >SVWN> D S>M> J>JN <QBTH B MTQN BJTH BRJ >ZDHR B ZBN> D <LJMWTK W L> TTL L NWKRJ> XJLK B<J PYTK MN KWL >R< PQ<T> VBT> L MZR< ZR<K B TWLDTK TKJL>JT W HKN> HWJN <LLTK W L> KR D HW THW> CRBTK >NTT> GJRT> L L> MDM TTXCB >NTT GBR> DJN >JK MGDL> HJ D MWT> L >JLJN D MTDBQJN LH TTXCB >NTT> DJN RCJ<T> B MNTH D GBR> <WL> TTJHB >NTT> DJN ZDJQT> L >JN> D DXL L MRJ> TTJHB L >NTT> D L> BHT> Y<R> NBLJH BRT> DJN >SKMTNJT> >P MN B<LH TTKXD >NTT> DJN D L> BHT> >JK KLB> TTXCB W >JD> D DXL> MN MRJ> >JT BH BHTT> >NTT> D MJQR> B<LH L KL NC XKJMT> TTXCB RCJ<T> DJN D MY<R> B G>JWTH L KL NC TTJD< >NTT> DJN VBT> VWBWHJ L B<LH MNJN> GJR D CNJ> D XJWHJ ><JPJN >NWN XRJNH D >NTT> MKJKWT> HW W >JK >CT> DQJQT> HKN> TTXZ> >NTT> QHLNJT> W PKNJT> >JK QRN> MLBVNJT> D QRB> TTXCB NPC> DJN D KL BR NC D >JT L HLJN KLHJN TTRM> B CGWCJ> D QRB> XJ> B >WLYN> NTDBRWN <L TRTJN YBWN TWR LBJ W <L TLT SGJ >TB>C LJ <L GBR> BR X>R> D >TMSKN W >YVRK W <L >NC> MRJ CM> D >TBYRW  ...

# %% [markdown]
# ## Passage indicators

# %% [markdown]
# If you want books, chapters and verses marked, you can achieve it in the following way:

# %%
plainx_file = outfile("calap_plainx.txt")

the_book = None
the_chapter = None
the_verse = None

for i in NN():
    this_type = F.otype.v(i)
    if this_type == "word":
        the_text = F.surface_consonants.v(i)
        the_suffix = ' '
        plainx_file.write(the_text + the_suffix)
    elif this_type == "book":
        the_book = F.book.v(i)
        sys.stderr.write("\r{:>6} {:<30}".format(i, the_book)) 
        plainx_file.write("\n{}".format(the_book))
    elif this_type == "chapter":
        the_chapter = F.chapter.v(i)
        plainx_file.write("\n{} {}".format(the_book, the_chapter))
    elif this_type == "verse":
        the_verse = F.verse.v(i)
        plainx_file.write("\n{}:{} ".format(the_chapter, the_verse))
sys.stderr.write("\n")

plainx_file.close()
# Out:
# 141612 II_Kings
# 141613 Sirach

# %%
# !head -n 10 {my_file('calap_plainx.txt')}
# Out:
# I_Kings
# I_Kings 1
# 1:1 W MLK> DWJD S>B W <L B CNJ> W MKSJN HWW LH B LBWC> W L> CXN
# 1:2 W >MRW LH <BDWHJ H> <BDJK QDMJK NB<WN L MRN MLK> <LJMT> BTWLT> W TQWM QDM MLK> W THW> LH MCMCNJT> W TCKB B <WBK W NCXN L MRN MLK>
# 1:3 W B<W <LJMT> D CPJR> B KLH TXWM> D >JSRJL W >CKXW L >BJCG CJLWMJT> W >JTJWH L MLK>
# 1:4 W <LJMT> CPJR> HWT B XZWH VB W HWT L MLK> MCMCNJT> W MCMC> LH W MLK> L> JD<H
# 1:5 W >DWNJ> BR XGJT MTRWRB W >MR >N> >MLK W <BD LH MRKBT> W PRC> W XMCJN GBRJN D RHVJN HWW QDMWHJ
# 1:6 W L> K>> BH >BWHJ MN JWMWHJ W >MR LH MVL MN> HKN> <BD >NT W >P HW CPJR HW> B XZWH VB W LH JLDT BTR >BCLWM
# 1:7 W HWW PTGMWHJ <M JW>B BR YWRJ> W <M >BJTR KHN> W M<DRJN BTR >DWNJ>

# %% [markdown]
# ## Verse list

# %% [markdown]
# We can get the text in a quite different way: just read it from the *primary data*.
#
# Let us do that per verse.

# %%
verse_file = outfile("calap_verses.txt")

for i in F.otype.s('verse'):
    the_text = ''.join([txt for (j, txt) in P.data(i)])
    the_verse = F.verse_label.v(i)
    verse_file.write("{}\n{}\n".format(the_verse, the_text))

verse_file.close()

# %%
# !head -n 10 {my_file('calap_verses.txt')}
# Out:
# 1R 1,1
# W MLK> DWJD S>B W <L B CNJ> W MKSJN HWW LH B LBWC> W L> CXN
# 1R 1,2
# W >MRW LH <BDWHJ H> <BDJK QDMJK NB<WN L MRN MLK> <LJMT> BTWLT> W TQWM QDM MLK> W THW> LH MCMCNJT> W TCKB B <WBK W NCXN L MRN MLK>
# 1R 1,3
# W B<W <LJMT> D CPJR> B KLH TXWM> D >JSRJL W >CKXW L >BJCG CJLWMJT> W >JTJWH L MLK>
# 1R 1,4
# W <LJMT> CPJR> HWT B XZWH VB W HWT L MLK> MCMCNJT> W MCMC> LH W MLK> L> JD<H
# 1R 1,5
# W >DWNJ> BR XGJT MTRWRB W >MR >N> >MLK W <BD LH MRKBT> W PRC> W XMCJN GBRJN D RHVJN HWW QDMWHJ

# %% [markdown]
# ## Empty words

# %% [markdown]
# There are words that have an empty representation.
#
# Let us have a closer look.
# How frequent are they and to what lexemes do they correspond, and what is their part of speech?

# %%
ewords = collections.defaultdict(lambda: [])
verse = None

for i in NN(test=F.otype.v, values=['verse', 'word']):
    if F.otype.v(i) == 'verse':
        verse = i
        continue
    text = F.surface_consonants.v(i)
    if text == '':
        lex = lexeme.v(i)
        pos = F.psp.v(i)
        ewords[(lex, pos)].append(verse)

for (item, occs) in sorted(ewords.items(), key=lambda x: (-len(x[1]), x[0][1], x[0][0])):
    print("{:>6} x {:<15} = {:>10} in {}{}".format(
        len(occs), 
        item[1], 
        item[0], 
        "; ".join([F.verse_label.v(j) for j in occs][0:5]),
        ' ...' if len(occs) > 20 else '',
    ))

# %%
close()
# Out:
#  1m 51s Results directory:
# /Users/dirk/laf-fabric-data/calap/tasks/plain
# .DS_Store                              6148 Thu Apr 17 18:26:31 2014
# __log__plain.txt                        271 Thu Apr 17 18:41:18 2014
# calap_plain.txt                      217318 Thu Apr 17 18:37:31 2014
# calap_plainx.txt                     236092 Thu Apr 17 18:38:29 2014
# calap_verses.txt                     244614 Thu Apr 17 18:39:32 2014
